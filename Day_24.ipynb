# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushnandan2025/Summer_Assignment_25CSE051/blob/main/Day_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile strrot.c
# #include <stdio.h>
# #include <string.h>
# int main(){
#   char str1[100],str2[100],temp[200];
#   printf("Enter first string: ");
#   scanf("%s",str1);
#   printf("Enter second string: ");
#   scanf("%s",str2);
#   if(strlen(str1)!=strlen(str2)){
#     printf("not rotation");
#     return 0;}
#
#   strcpy(temp,str1);
#   strcat(temp,str2);
#   if(strstr(temp,str2))
#   printf("string are rotation of each other");
#   else
#   printf("string are not rotation of each other");
#   return 0;
# }
# Out:
# Writing strrot.c

# %%
# !gcc strrot.c

# %%
# !./a.out
# Out:
# Enter first string: asdfghjkl
# Enter second string: lkjhgfdsa
# string are rotation of each other

# %%
# %%writefile comst.c
# #include <stdio.h>
# int main(){
#   char str[100];
#   int i,count;
#   printf("enter the string:");
#   scanf("%s",str);
#   for(i=0;str[i]!='\0';i++){
#     count=1;
#     while(str[i]==str[i+1]){
#       count++;
#       i++;
#
#     }
#   printf("%c%d",str[i],count);
#
# }
# return 0;}
# Out:
# Overwriting comst.c

# %%
# !gcc comst.c

# %%
# !./a.out
# Out:
# enter the string:aaabbcccc
# a3b2c4

# %%
# %%writefile lws.c
# #include <stdio.h>
# #include <string.h>
# int main(){
#   char str[200],longest[50];
#   int i=0,j=0,max=0;
#   char word[50];
#   printf("enter a sentence:");
#   fgets(str,sizeof(str),stdin);
#   while(1){
#     if(str[i]!=' '&& str[i]!='\0' && str[i]!='\n'){
#       word[j++]=str[i];
#
#     }else{
#       word[j] ='\0';
#       if(j>max){
#         max=j;
#         strcpy(longest,word);
#
#       }
#       j=0;
#       if(str[i]=='\0' || str[i]=='\n'){
#         break;
#       }
#     }
#     i++;
#   }
#   printf("longest word = %s",longest);
#   return 0;
#   }
# Out:
# Writing lws.c

# %%
# !gcc lws.c

# %%
# !./a.out
# Out:
# enter a sentence:He is a hero
# longest word = hero

# %%
# %%writefile redup.c
# #include <stdio.h>
# int main(){
#   char str[100];
#   printf("enter a string");
#   scanf("%s",str);
#   printf("string after removing duplicates:");
#
#   for(int i=0;str[i]!='\0';i++){
#     int duplicate=0;
#     for(int j=0;j<i;j++){
#       if(str[i]==str[j]){
#         duplicate=1;
#         break;
#       }
#     }
#     if(duplicate==0){
#       printf("%c",str[i]);
#     }}
#
#   return 0;
# }
# Out:
# Overwriting redup.c

# %%
# !gcc redup.c

# %%
# !./a.out
# Out:
# enter a stringasdea
# string after removing duplicates:asde
