# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushnandan2025/Summer_Assignment_25CSE051/blob/main/Day_17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile merge.c
# #include <stdio.h>
# int main(){
# int n1,n2;
# printf("enter size of first array");
# scanf("%d",&n1);
# int a[n1];
# printf("enter first array elements:\n");
# for(int i=0;i<n1;i++)
#
# scanf("%d",&a[i]);
# printf("enter size of second array");
# scanf("%d",&n2);
# int b[n2];
# printf("enter second array elements:\n");
# for(int i=0;i<n2;i++)
# scanf("%d",&b[i]);
#
# int c[n1+n2];
# for(int i=0;i<n1;i++)
# c[i]=a[i];
# for(int i=0;i<n2;i++)
# c[n1+i]=b[i];
# printf("merged array is:\n");
# for(int i=0;i<n1+n2;i++)
# printf("%d ",c[i]);
# return 0;
# }
# Out:
# Writing merge.c

# %%
# !gcc merge.c

# %%
# !./a.out
# Out:
# enter size of first array4
# enter first array elements:
# 1
# 2
# 3
# 4
# enter size of second array5
# enter second array elements:
# 5
# 6
# 7
# 8
# 9
# merged array is:
# 1 2 3 4 5 6 7 8 9

# %%
# %%writefile union.c
# #include <stdio.h>
# int main(){
#   int n1,n2;
#   printf("enter size of first array");
#   scanf("%d",&n1);
#   int a[n1];
#   printf("enter first array elements:\n");
#   for(int i=0;i<n1;i++)
#   scanf("%d",&a[i]);
#   printf("enter size of second array");
#   scanf("%d",&n2);
#   int b[n2];
#   printf("enter second array elements:\n");
#   for(int i=0;i<n2;i++)
#   scanf("%d",&b[i]);
#
#   printf("union:");
#   for(int i=0;i<n1;i++)
#   printf("%d ",a[i]);
#   for(int i=0;i<n2;i++){
#     int found=0;
#     for(int j=0;j<n1;j++){
#       if(b[i]==a[j]){
#         found=1;
#         break;
#       }
#     }
#     if(found==0)
#     printf("%d ",b[i]);
#   }
#   return 0;
#   }
# Out:
# Writing union.c

# %%
# !gcc union.c

# %%
# !./a.out
# Out:
# enter size of first array3
# enter first array elements:
# 1
# 2
# 3
# enter size of second array4
# enter second array elements:
# 3
# 4
# 5
# 6
# union:1 2 3 4 5 6

# %%
# %%writefile intsec.c
# #include <stdio.h>
# int main(){
#   int n1,n2;
#   printf("enter size of first array");
#   scanf("%d",&n1);
#   int a[n1];
#   printf("enter first array elements:\n");
#   for(int i=0;i<n1;i++)
#   scanf("%d",&a[i]);
#   printf("enter size of second array");
#   scanf("%d",&n2);
#   int b[n2];
#   printf("enter second array elements:\n");
#   for(int i=0;i<n2;i++)
#   scanf("%d",&b[i]);
#
#   printf("intersection");
#   for(int i=0;i<n1;i++){
#
#     for(int j=0;j<n2;j++){
#
#         if(a[i]==b[j]){
#           printf("%d ",a[i]);
#           break;
#         }
#
#     }
#   }
#   return 0;
#   }
# Out:
# Writing intsec.c

# %%
# !gcc intsec.c

# %%
# !./a.out
# Out:
# enter size of first array3
# enter first array elements:
# 2
# 3
# 4
# enter size of second array3
# enter second array elements:
# 3
# 4
# 5
# intersection3 4

# %%
# %%writefile comel.c
# #include <stdio.h>
# int main() {
#   int n1,n2;
#   printf("enter size of first array");
#   scanf("%d",&n1);
#   int a[n1];
#   printf("enter first array elements:\n");
#   for(int i=0;i<n1;i++)
#   scanf("%d",&a[i]);
#   printf("enter size of second array");
#   scanf("%d",&n2);
#   int b[n2];
#   printf("enter second array elements:\n");
#   for(int i=0;i<n2;i++)
#   scanf("%d",&b[i]);
#   printf("common elements");
#   for(int i=0;i<n1;i++){
#
#     for(int j=0;j<n2;j++){
#
#         if(a[i]==b[j]){
#           printf("%d ",a[i]);
#           break;
# }
#     }
#   }
#   return 0;
# }
# Out:
# Writing comel.c

# %%
# !gcc comel.c

# %%
# !./a.out
# Out:
# enter size of first array3
# enter first array elements:
# 1
# 2
# 3
# enter size of second array3
# enter second array elements:
# 2
# 3
# 4
# common elements2 3
