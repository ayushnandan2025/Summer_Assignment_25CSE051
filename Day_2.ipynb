# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushnandan2025/Summer_Assignment_25CSE051/blob/main/Day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile sum.c
# #include <stdio.h>
# int main(){
#   int n,sum=0,digit;
#   printf("enter no:");
#   scanf("%d",&n);
#   while(n>0){
#     digit=n%10;
#     sum=sum+digit;
#     n=n/10;
#   }
#   printf("sum of digits:%d",sum);
#   return 0;
# }
# Out:
# Writing sum.c

# %%
# !gcc sum.c

# %%
# !./a.out
# Out:
# enter no:52
# sum of digits:7

# %%
# %%writefile reverse.c
# #include <stdio.h>
# int main(){
#   int n,rev=0,digit;
#   printf("enter no:");
#   scanf("%d",&n);
#   while(n>0){
#     digit=n%10;
#     rev=rev*10+digit;
#     n=n/10;
# }
# printf("reverse no=%d",rev);
# return 0;
# }
# Out:
# Writing reverse.c

# %%
# !gcc reverse.c

# %%
# !./a.out
# Out:
# enter no:32
# reverse no=23

# %%
# %%writefile pod.c
# #include <stdio.h>
# int main(){
#   int n,pod=1,digit;
#   printf("enter no:");
#   scanf("%d",&n);
#   while(n>0){
#     digit=n%10;
#     pod=pod*digit;
#     n=n/10;
# }
# printf("product of digits=%d",pod);
# return 0;
# }
# Out:
# Writing pod.c

# %%
# !gcc pod.c

# %%
# !./a.out
# Out:
# enter no:42
# product of digits=8

# %%
# %%writefile palindrome.c
# #include <stdio.h>
# int main(){
#   int n,rev=0,digit,original;
#   printf("enter no:");
#   scanf("%d",&n);
#   original=n;
#   while(n>0){
#     digit=n%10;
#     rev=rev*10+digit;
#     n=n/10;
# }
# if(original==rev){
#   printf("palindrome");
#  } else
#   printf("not palindrome");
# return 0;
# }
# Out:
# Overwriting palindrome.c

# %%
# !gcc palindrome.c

# %%
# !./a.out
# Out:
# enter no:32
# not palindrome
